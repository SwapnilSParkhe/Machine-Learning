# %% [markdown]
# # Breast Cancer Wisconsin
#
# ### 1) Problem Statement
# **Dataset** -
#
# https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data
#
# **Metadata** -
# ![](Images/Data_Info.png)
#
# **Data info** -
# ![](Images/Attribute_Info.png)

# %% [markdown]
# ### 2) Requirements

# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 3) Data Imports and Inspection

# %%
df= pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data', header=None)

# %%
df.head()
# Out:
#          0  1      2      3       4       5        6        7       8   \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#         9   ...     22     23      24      25      26      27      28      29  \
# 0  0.14710  ...  25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119  0.2654
# 1  0.07017  ...  24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416  0.1860
# 2  0.12790  ...  23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504  0.2430
# 3  0.10520  ...  14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869  0.2575
# 4  0.10430  ...  22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000  0.1625
#
#        30       31
# 0  0.4601  0.11890
# 1  0.2750  0.08902
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       569 non-null    int64
#  1   1       569 non-null    object
#  2   2       569 non-null    float64
#  3   3       569 non-null    float64
#  4   4       569 non-null    float64
#  5   5       569 non-null    float64
#  6   6       569 non-null    float64
#  7   7       569 non-null    float64
#  8   8       569 non-null    float64
#  9   9       569 non-null    float64
#  10  10      569 non-null    float64
#  11  11      569 non-null    float64
#  12  12      569 non-null    float64
#  13  13      569 non-null    float64
#  14  14      569 non-null    float64
#  15  15      569 non-null    float64
#  16  16      569 non-null    float64
#  17  17      569 non-null    float64
#  18  18      569 non-null    float64
#  19  19      569 non-null    float64
# ...

# %%
plt.figure(figsize=(16,8))
sns.heatmap(df.isnull(), cbar=False)
plt.show()

# %% [markdown]
# ### 4) Exploratory Data Analysis

# %% [markdown]
# **4.1) Univariate**

# %%
df.describe(include='all').transpose()
# Out:
#    count unique  top freq         mean          std        min       25%  \
# 0    569    NaN  NaN  NaN  3.03718e+07  1.25021e+08       8670    869218
# 1    569      2    B  357          NaN          NaN        NaN       NaN
# 2    569    NaN  NaN  NaN      14.1273      3.52405      6.981      11.7
# 3    569    NaN  NaN  NaN      19.2896      4.30104       9.71     16.17
# 4    569    NaN  NaN  NaN       91.969       24.299      43.79     75.17
# 5    569    NaN  NaN  NaN      654.889      351.914      143.5     420.3
# 6    569    NaN  NaN  NaN    0.0963603    0.0140641    0.05263   0.08637
# 7    569    NaN  NaN  NaN     0.104341    0.0528128    0.01938   0.06492
# 8    569    NaN  NaN  NaN    0.0887993    0.0797198          0   0.02956
# 9    569    NaN  NaN  NaN    0.0489191    0.0388028          0   0.02031
# 10   569    NaN  NaN  NaN     0.181162    0.0274143      0.106    0.1619
# 11   569    NaN  NaN  NaN    0.0627976   0.00706036    0.04996    0.0577
# ...

# %%
sns.countplot(x=1, data=df)
plt.show()
df[1].value_counts(normalize=True)*100
# Out:
# B    62.741652
# M    37.258348
# Name: 1, dtype: float64

# %%
df.hist(figsize=(16,20))
plt.show()
plt.tight_layout()

# %%
df.boxplot(figsize=(16,4))

fig, axs = plt.subplots(4,8, figsize = (16, 10))
ax=axs.flatten()

for i, col in enumerate([col for col in df.columns if df[col].dtype!='object']):
    sns.boxplot(y=col, data=df, ax=ax[i])
    plt.tight_layout()

# %% [markdown]
# **4.2) Bivariate**

# %%
fig, axs = plt.subplots(4,8, figsize = (16, 10))
ax=axs.flatten()

for i, col in enumerate([col for col in df.columns if df[col].dtype!='object']):
    sns.boxplot(x=1, y=col, data=df, ax=ax[i])
    plt.tight_layout()

# %%
plt.figure(figsize=(18,10))
sns.heatmap(df.corr(), cmap='plasma')
plt.title('Correlation among numeric vars')
plt.show()
